# %%
## 1-1
import pandas as pd
# 데이터 분석 및 전처리
import numpy as np
# 숫자처리
import matplotlib.pyplot as plt
# 데이터 시각화
from sklearn.neighbors import KNeighborsRegressor
                                #knn
from sklearn.linear_model import LinearRegression
                            ## ML 알고리즘
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score
                            ## 성능평가 모듈
from sklearn.model_selection import train_test_split
                            ## 데이터셋 분리 관련 모듈
                            ## 학습/검증/테스트 
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
                            ## 정규화, 컬럼추가
                            
import RegressionModule as rem

# %%
mpgDF = pd.DataFrame(pd.read_csv('../data/auto_mpg.csv'))
mpgDF['horsepower'] = mpgDF['horsepower'].replace('?', 'nan')
mpgDF = mpgDF.ffill()

# %%
mpgDF.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0        8.0         307.0        130  3504.0          12.0          70
# 1  15.0        8.0         350.0        165  3693.0          11.5          70
# 2  18.0        8.0         318.0        150  3436.0          11.0          70
# 3  16.0        8.0         304.0        150  3433.0          12.0          70
# 4  17.0        8.0         302.0        140  3449.0          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
mpgDF['horsepower'] = mpgDF['horsepower'].astype(float)
mpgDF = mpgDF.ffill()
mpgDF.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
mpgDF.isna().sum()
mpgDF['weight']=mpgDF['weight'].ffill()

# %%
plt.plot(mpgDF['weight'],mpgDF['mpg'], '.')

# %%
# basic plot
plt.boxplot(mpgDF['weight'])
plt.show()

# %% [markdown]
# mpg와 연관성 있는 데이터.
# - cylinder, displacement, horsepower, weight
# - weight만.

# %%
# feature = mpgDF[['horsepower', 'displacement','weight']]
# feature = mpgDF[['displacement','weight']]
feature = mpgDF[['weight']]
target = mpgDF['mpg']

# %%
rem.ft_choice(feature, target, 'lr')
# Out:
# Index(['weight'], dtype='object')
# X_train => 2D (303, 1) / X_test => 2D, (101, 1)
# y_train => 1D (303,), / y_test => 1D, (101,)
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (242, 1) 2 D / 242
# (243, 1) 2 D / 243
# (243, 1) 2 D / 243
#        alpha  train_score  test_score     diff  train_loss  test_loss  \
# 0.1      0.1     0.687598    0.675018  0.01258     4.21964   4.236302
# 0.5      0.5     0.687598    0.675018  0.01258     4.21964   4.236302
# 1.0      1.0     0.687598    0.675018  0.01258     4.21964   4.236302
# 1.5      1.5     0.687598    0.675018  0.01258     4.21964   4.236302
# 2.0      2.0     0.687598    0.675018  0.01258     4.21964   4.236302
# 2.5      2.5     0.687598    0.675018  0.01258     4.21964   4.236302
# 3.0      3.0     0.687598    0.675018  0.01258     4.21964   4.236302
# 5.0      5.0     0.687598    0.675018  0.01258     4.21964   4.236302
# 10.0    10.0     0.687598    0.675018  0.01258     4.21964   4.236302
# 50.0    50.0     0.687598    0.675018  0.01258     4.21964   4.236302
# 100.0  100.0     0.687598    0.675018  0.01258     4.21964   4.236302
#
#             coef
# 0.1    [-0.0077]
# 0.5    [-0.0077]
# 1.0    [-0.0077]
# 1.5    [-0.0077]
# 2.0    [-0.0077]
# 2.5    [-0.0077]
# 3.0    [-0.0077]
# 5.0    [-0.0077]
# 10.0   [-0.0077]
# 50.0   [-0.0077]
# 100.0  [-0.0077]

# %%
rem.ft_choice(feature, target, 'poly')
# Out:
# Index(['weight'], dtype='object')
# X_train => 2D (303, 1) / X_test => 2D, (101, 1)
# y_train => 1D (303,), / y_test => 1D, (101,)
# poly 적용
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (242, 3) 2 D / 242
# (243, 3) 2 D / 243
# (243, 3) 2 D / 243
#        alpha  train_score  test_score      diff  train_loss  test_loss  \
# 0.1      0.1     0.703562    0.688665  0.014897    4.109825   4.135037
# 0.5      0.5     0.703562    0.688665  0.014897    4.109825   4.135037
# 1.0      1.0     0.703562    0.688665  0.014897    4.109825   4.135037
# 1.5      1.5     0.703562    0.688665  0.014897    4.109825   4.135037
# 2.0      2.0     0.703562    0.688665  0.014897    4.109825   4.135037
# 2.5      2.5     0.703562    0.688665  0.014897    4.109825   4.135037
# 3.0      3.0     0.703562    0.688665  0.014897    4.109825   4.135037
# 5.0      5.0     0.703562    0.688665  0.014897    4.109825   4.135037
# 10.0    10.0     0.703562    0.688665  0.014897    4.109825   4.135037
# 50.0    50.0     0.703562    0.688665  0.014897    4.109825   4.135037
# 100.0  100.0     0.703562    0.688665  0.014897    4.109825   4.135037
#
#                       coef
# 0.1    [0.0, -0.0161, 0.0]
# 0.5    [0.0, -0.0161, 0.0]
# 1.0    [0.0, -0.0161, 0.0]
# 1.5    [0.0, -0.0161, 0.0]
# 2.0    [0.0, -0.0161, 0.0]
# 2.5    [0.0, -0.0161, 0.0]
# 3.0    [0.0, -0.0161, 0.0]
# 5.0    [0.0, -0.0161, 0.0]
# 10.0   [0.0, -0.0161, 0.0]
# 50.0   [0.0, -0.0161, 0.0]
# 100.0  [0.0, -0.0161, 0.0]
